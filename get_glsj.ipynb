# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import gen_css
import add_current

# %%
glsj_response = requests.get('http://www.mwm.net.cn/web/bqym')
glsj_data = BeautifulSoup(glsj_response.text, 'html.parser')

# %%
glsj_data
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="webkit" name="renderer"/>
# <meta content="IE=EmulateIE9" http-equiv="X-UA-Compatible"/>
# <title>管理世界杂志社-本期要目</title>
# <script src="/Content/js/jquery-3.3.1.min.js"></script>
# <script src="/Content/js/webindex.js" type="text/javascript"></script>
# <link href="/Content/css/artical.css" rel="stylesheet"/>
# <link href="/Content/css/style.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/css/styleForCode.css" rel="stylesheet">
# <link href="/Content/css/public.css" rel="stylesheet" type="text/css"/>
# <link href="/Content/css/column.css" rel="stylesheet" type="text/css"/>
# </link></head>
# <body id="bodyId">
# <script type="text/javascript">
#     function searchBG() {
#         var obj = document.getElementById("searchContent");
#         obj.style.background = "none;";
#     }
#     function show(inputObj) {
#         var obj = document.getElementById("searchContent");
#         if (inputObj.value == "请输入查找内容") {
# ...
